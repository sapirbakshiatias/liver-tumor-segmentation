# %% [markdown]
# <a href="https://colab.research.google.com/github/sapirbakshiatias/liver-tumor-segmentation/blob/main/segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_12134/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %%
import os
os.listdir("/content/drive/MyDrive")
# Out:
# ['רוני נדב תאיר ושחר מנטוס ניסוי קולה ומנטוס.gdoc',
#  'רוני 2023',
#  'Colab Notebooks',
#  'Roni_Cohen_Resume.pdf',
#  'IMG_7688.png',
#  'Final_pr']

# %%
import os

dataset_path = "/content/drive/MyDrive/Final_pr"

os.listdir(dataset_path)
# Out:
# ['LITS Challenge', 'LITS-Challenge-Test-Data']

# %%
dataset_path = "/content/drive/MyDrive/Final_pr/LITS Challenge"

import os
os.listdir(dataset_path)[:10]
# Out:
# ['Training Batch 2',
#  'Training Batch 1',
#  'Training_Batch1.zip',
#  'Training_Batch2.zip']

# %%
dataset_path = "/content/drive/MyDrive/Final_pr/LITS Challenge/Training Batch 1"

import os
os.listdir(dataset_path)
# Out:
# []
